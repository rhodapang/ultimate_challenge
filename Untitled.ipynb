# %%
# import packages

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # import dataset

# %% [markdown]
# #### The dataset of logins
#
# It contains (simulated) timestamps of user logins in a particular geographic location.

# %% [markdown]
# The attached logins.json file contains (simulated) timestamps of user logins in a particular
# geographic location. Aggregate these login counts based on 15minute time intervals, and
# visualize and describe the resulting time series of login counts in ways that best characterize the
# underlying patterns of the demand. Please report/illustrate important features of the demand,
# such as daily cycles. If there are data quality issues, please report them.

# %%
df_login = pd.read_json(r'D:\Springboard\Github\ultimate_challenge_analysis\logins.json')

# %%
df_login.head()
# Out:
#            login_time
# 0 1970-01-01 20:13:18
# 1 1970-01-01 20:16:10
# 2 1970-01-01 20:16:37
# 3 1970-01-01 20:16:36
# 4 1970-01-01 20:26:21

# %%
df_login.shape
# Out:
# (93142, 1)

# %%
df_login['denote']=1

# %%
df_login
# Out:
#                login_time  denote
# 0     1970-01-01 20:13:18       1
# 1     1970-01-01 20:16:10       1
# 2     1970-01-01 20:16:37       1
# 3     1970-01-01 20:16:36       1
# 4     1970-01-01 20:26:21       1
# ...                   ...     ...
# 93137 1970-04-13 18:50:19       1
# 93138 1970-04-13 18:43:56       1
# 93139 1970-04-13 18:54:02       1
# 93140 1970-04-13 18:57:38       1
# 93141 1970-04-13 18:54:23       1
#
# [93142 rows x 2 columns]

# %%
df_login['hour'] = df_login['login_time'].dt.hour

# %%
# check the data type of each columns 
df_login.dtypes
# Out:
# login_time    datetime64[ns]
# denote                 int64
# hour                   int64
# dtype: object

# %%
df_login
# Out:
#                login_time  denote  hour
# 0     1970-01-01 20:13:18       1    20
# 1     1970-01-01 20:16:10       1    20
# 2     1970-01-01 20:16:37       1    20
# 3     1970-01-01 20:16:36       1    20
# 4     1970-01-01 20:26:21       1    20
# ...                   ...     ...   ...
# 93137 1970-04-13 18:50:19       1    18
# 93138 1970-04-13 18:43:56       1    18
# 93139 1970-04-13 18:54:02       1    18
# 93140 1970-04-13 18:57:38       1    18
# 93141 1970-04-13 18:54:23       1    18
#
# [93142 rows x 3 columns]

# %%
# group by the login hours of a day
df_hour = df_login[['denote', 'hour']]
df_hour = df_hour.groupby('hour').sum().reset_index()

#barplot of logins by hour 
plt.figure(figsize=(20,20))
sns.barplot(x='hour', y='denote', data=df_hour)
# Out:
# <AxesSubplot:xlabel='hour', ylabel='denote'>

# %%
login_seq_hour_new = df_login['denote'].groupby(['hour']).sum()
login_seq_hour_new.head(30)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-ad0da0271392> in <module>
# ----> 1 login_seq_hour_new = df_login['denote'].groupby(['hour']).sum()
#       2 login_seq_hour_new.head(30)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    1685             group_keys=group_keys,
#    1686             squeeze=squeeze,
# -> 1687             observed=observed,
#    1688         )
#    1689
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     407                 sort=sort,
#     408                 observed=observed,
# --> 409                 mutated=self.mutated,
#     410             )
#     411
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     596                 in_axis, name, level, gpr = False, None, gpr, None
#     597             else:
# --> 598                 raise KeyError(gpr)
#     599         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     600             # Add key to exclusions
#
# KeyError: 'hour'

# %%
login_seq_hour_new = df_login.resample('H',on='hour').denote.sum().sort_values(ascending=False)
login_seq_hour_new.head(30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-e720bb7deceb> in <module>
# ----> 1 login_seq_hour_new = df_login.resample('H',on='hour').denote.sum().sort_values(ascending=False)
#       2 login_seq_hour_new.head(30)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level)
#    8113             base=base,
#    8114             key=on,
# -> 8115             level=level,
#    8116         )
#    8117
#
# ~\Anaconda3\lib\site-packages\pandas\core\resample.py in resample(obj, kind, **kwds)
#    1268     """
#    1269     tg = TimeGrouper(**kwds)
# -> 1270     return tg._get_resampler(obj, kind=kind)
#    1271
#    1272
#
# ~\Anaconda3\lib\site-packages\pandas\core\resample.py in _get_resampler(self, obj, kind)
#    1402
#    1403         raise TypeError(
# -> 1404             "Only valid with DatetimeIndex, "
#    1405             "TimedeltaIndex or PeriodIndex, "
#    1406             f"but got an instance of '{type(ax).__name__}'"
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'Int64Index'

# %%
#  Aggregate these login counts based on 15minute time intervals
# question: how could I plot that it is to show which time period would be the most busy time in one day?
# if we could understand when the most busiest time are, then improve the service quality 
login_seq = df_login.resample('15T',on='login_time').denote.sum().sort_values(ascending=False)
login_seq.head(30)
# Out:
# login_time
# 1970-03-01 04:30:00    73
# 1970-04-04 05:30:00    66
# 1970-04-04 01:30:00    64
# 1970-04-04 01:15:00    63
# 1970-04-01 23:30:00    60
# 1970-04-04 05:00:00    60
# 1970-04-04 05:15:00    59
# 1970-04-04 04:45:00    59
# 1970-04-04 01:45:00    56
# 1970-03-13 22:15:00    55
# 1970-04-04 01:00:00    54
# 1970-03-17 01:30:00    53
# 1970-04-04 00:30:00    53
# 1970-03-29 04:45:00    52
# 1970-03-08 04:45:00    51
# 1970-04-03 22:45:00    50
# 1970-03-29 02:15:00    50
# 1970-04-04 00:45:00    50
# 1970-02-15 04:45:00    50
# 1970-03-28 04:30:00    50
# 1970-03-01 04:45:00    48
# 1970-04-04 03:00:00    47
# 1970-03-07 03:00:00    47
# 1970-03-08 05:00:00    47
# 1970-04-03 23:15:00    47
# 1970-03-07 04:45:00    46
# 1970-04-04 03:15:00    46
# 1970-02-07 04:30:00    46
# 1970-03-22 04:00:00    46
# 1970-03-22 01:30:00    46
# Name: denote, dtype: int64

# %%
login_seq_hour = df_login.resample('H',on='login_time').denote.sum().sort_values(ascending=False)
login_seq_hour.head(30)
# Out:
# login_time
# 1970-04-04 01:00:00    237
# 1970-04-04 05:00:00    226
# 1970-03-01 04:00:00    205
# 1970-04-04 04:00:00    174
# 1970-04-04 00:00:00    173
# 1970-03-13 22:00:00    169
# 1970-03-29 04:00:00    168
# 1970-02-15 04:00:00    164
# 1970-03-08 04:00:00    159
# 1970-03-22 04:00:00    158
# 1970-03-29 02:00:00    157
# 1970-03-17 01:00:00    156
# 1970-03-13 21:00:00    156
# 1970-04-05 04:00:00    156
# 1970-04-12 04:00:00    153
# 1970-04-12 03:00:00    153
# 1970-03-07 03:00:00    152
# 1970-03-21 04:00:00    150
# 1970-04-04 03:00:00    150
# 1970-03-29 03:00:00    147
# 1970-03-15 04:00:00    147
# 1970-04-03 23:00:00    147
# 1970-02-21 03:00:00    146
# 1970-02-22 04:00:00    145
# 1970-03-28 04:00:00    142
# 1970-02-28 02:00:00    140
# 1970-03-17 00:00:00    140
# 1970-02-21 01:00:00    139
# 1970-04-03 22:00:00    138
# 1970-03-07 04:00:00    138
# Name: denote, dtype: int64

# %%
login_seq_hour.plot(figsize=(15,15))
# Out:
# <AxesSubplot:xlabel='login_time'>

# %%
login_seq.value_counts(ascending=True).head(20)
# Out:
# 51    1
# 54    1
# 52    1
# 55    1
# 66    1
# 73    1
# 64    1
# 63    1
# 48    1
# 56    1
# 53    2
# 60    2
# 59    2
# 44    3
# 47    4
# 50    5
# 46    6
# 43    8
# 45    8
# 40    8
# Name: denote, dtype: int64

# %%
login_seq.value_counts(ascending=False).head(20)
# Out:
# 2     726
# 4     706
# 3     703
# 5     658
# 1     638
# 6     632
# 7     539
# 8     508
# 9     437
# 10    420
# 11    413
# 0     407
# 13    311
# 12    309
# 14    288
# 15    246
# 16    219
# 17    213
# 18    152
# 19    146
# Name: denote, dtype: int64

# %% [markdown]
# Finding: From above result, we understand that the most frequent login 15 mins could reach to 73

# %%
login_seq_1 = pd.DataFrame(login_seq)
login_seq_1.plot(figsize=(15,15))
plt.show()

# %%
#  Aggregate these login counts based on 15minute time intervals
plt.hist(df_login.resample('15T',on='login_time').denote.sum())
# Out:
# (array([5.009e+03, 2.686e+03, 1.231e+03, 5.320e+02, 2.050e+02, 8.300e+01,
#         2.800e+01, 6.000e+00, 6.000e+00, 2.000e+00]),
#  array([ 0. ,  7.3, 14.6, 21.9, 29.2, 36.5, 43.8, 51.1, 58.4, 65.7, 73. ]),
#  <BarContainer object of 10 artists>)

# %%
# From below histogram, we understand most of the use could 
df_login.resample('15T',on='login_time').denote.sum().hist(bins=70)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Users Sample dataset
#
# It is a sample dataset of a cohort of users who signed up for an Ultimate account in January 2014. The data was pulled several months later; we consider a user retained if they were “active” (i.e. took a trip) in the preceding 30 days.
#
# Data description
# ● city: city this user signed up in
# ● phone: primary device for this user
# ● signup_date: date of account registration; in the form ‘YYYY MM DD’
# ● last_trip_date: the last time this user completed a trip; in the form ‘YYYY MM DD’
# ● avg_dist: the average distance in miles per trip taken in the first 30 days after signup
# ● avg_rating_by_driver: the rider’s average rating over all of their trips
# ● avg_rating_of_driver: the rider’s average rating of their drivers over all of their trips
# ● surge_pct: the percent of trips taken with surge multiplier > 1
# ● avg_surge: The average surge multiplier over all of this user’s trips
# ● trips_in_first_30_days: the number of trips this user took in the first 30 days after
# signing up
# ● ultimate_black_user: TRUE if the user took an Ultimate Black in their first 30 days;
# FALSE otherwise
# ● weekday_pct: the percent of the user’s trips occurring during a weekday

# %%
df = pd.read_json(r'D:\Springboard\Github\ultimate_challenge_analysis\ultimate_data_challenge.json')

# %%
df.head()
# Out:
#              city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 0  King's Landing                       4  2014-01-25                   4.7
# 1         Astapor                       0  2014-01-29                   5.0
# 2         Astapor                       3  2014-01-06                   4.3
# 3  King's Landing                       9  2014-01-10                   4.6
# 4      Winterfell                      14  2014-01-27                   4.4
#
#    avg_surge last_trip_date    phone  surge_pct  ultimate_black_user  \
# 0       1.10     2014-06-17   iPhone       15.4                 True
# 1       1.00     2014-05-05  Android        0.0                False
# 2       1.00     2014-01-07   iPhone        0.0                False
# 3       1.14     2014-06-29   iPhone       20.0                 True
# 4       1.19     2014-03-15  Android       11.8                False
#
#    weekday_pct  avg_dist  avg_rating_by_driver
# 0         46.2      3.67                   5.0
# 1         50.0      8.26                   5.0
# 2        100.0      0.77                   5.0
# 3         80.0      2.36                   4.9
# 4         82.4      3.13                   4.9

# %%
df.shape
# Out:
# (50000, 12)
